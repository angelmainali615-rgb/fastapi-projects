# %%
import pandas as pd
import numpy as np
from io import StringIO
employees="""id,name,age,salary,department,join_date
1,Alice,25,50000,HR,2021-01-15
2,Bob,,60000,Engineering,2020-06-20
3,Charlie,35,,Engineering,2019-03-10
4,David,29,55000,,2022-08-01
5,Eva,NaN,48000,HR,
6,,40,70000,Finance,2018-11-30
7,Frank,28,52000,Engineering,2021-09-12
8,Grace,,58000,HR,2020-02-18
9,Hannah,31,,Marketing,2019-07-25
10,Ian,45,80000,Finance,
11,Jack,27,48000,,2021-11-05
12,Karen,34,62000,Engineering,2018-04-14
13,Liam,NaN,54000,HR,2022-01-09
14,Mia,26,,Marketing,2020-05-21
15,Noah,38,72000,Finance,2017-10-30
16,Olivia,,51000,HR,2021-03-17
17,Paul,41,69000,,2016-08-19
18,Quinn,33,,Engineering,2019-12-01
19,Rachel,29,56000,Marketing,2022-06-11
20,Steve,NaN,75000,Finance,
21,Tina,24,47000,HR,2021-07-07
22,Uma,36,,Engineering,2018-09-23
23,Victor,39,68000,,2017-02-14
24,Wendy,,59000,Marketing,2020-10-05
25,Xavier,42,81000,Finance,2016-11-11
26,Yara,27,,HR,2022-04-03
27,Zack,31,61000,Engineering,
28,Anna,35,64000,Marketing,2019-06-06
29,Brian,NaN,58000,HR,2020-01-01
30,Cathy,28,,Engineering,2021-08-15
31,Derek,44,77000,Finance,2015-12-20
32,Elena,,53000,Marketing,2020-03-08
33,Felix,37,,Engineering,2018-07-27
34,Gina,26,49000,HR,2022-09-01
35,Harry,40,71000,,2017-05-13
36,Irene,32,,Marketing,
37,Jason,29,56000,Engineering,2021-04-22
38,Kelly,NaN,52000,HR,2019-11-09
39,Leo,34,,Finance,2018-01-30
40,Mona,25,47000,,2022-02-14
41,Nate,,66000,Engineering,2020-06-06
42,Opal,38,,HR,2017-09-19
43,Peter,45,82000,Finance,2016-04-25
44,Queen,27,50000,Marketing,
45,Ron,36,,Engineering,2019-08-18
46,Sara,31,59000,,2021-12-01
47,Tom,NaN,61000,Engineering,2020-10-10
48,Ursula,28,,HR,2022-05-05
49,Vincent,41,76000,Finance,
50,Willow,33,63000,Marketing,2018-06-16
51,Xena,,54000,HR,2019-03-03
52,Yusuf,39,,Engineering,2017-07-07
53,Zara,24,46000,,2022-11-11
54,Adam,35,65000,Finance,2016-02-02
55,Bella,29,,Marketing,2020-09-09
56,Carl,NaN,70000,Engineering,
57,Daisy,26,48000,HR,2021-01-01
58,Ethan,,72000,Finance,2018-08-08
59,Fiona,34,,Marketing,2019-04-04
60,George,43,79000,,2015-05-05"""


df=pd.read_csv(StringIO(employees))
df.to_csv("employees.csv",index=False)
df
# Out:
#     id     name   age   salary   department   join_date
# 0    1    Alice  25.0  50000.0           HR  2021-01-15
# 1    2      Bob   NaN  60000.0  Engineering  2020-06-20
# 2    3  Charlie  35.0      NaN  Engineering  2019-03-10
# 3    4    David  29.0  55000.0          NaN  2022-08-01
# 4    5      Eva   NaN  48000.0           HR         NaN
# 5    6      NaN  40.0  70000.0      Finance  2018-11-30
# 6    7    Frank  28.0  52000.0  Engineering  2021-09-12
# 7    8    Grace   NaN  58000.0           HR  2020-02-18
# 8    9   Hannah  31.0      NaN    Marketing  2019-07-25
# 9   10      Ian  45.0  80000.0      Finance         NaN
# 10  11     Jack  27.0  48000.0          NaN  2021-11-05
# 11  12    Karen  34.0  62000.0  Engineering  2018-04-14
# 12  13     Liam   NaN  54000.0           HR  2022-01-09
# 13  14      Mia  26.0      NaN    Marketing  2020-05-21
# 14  15     Noah  38.0  72000.0      Finance  2017-10-30
# 15  16   Olivia   NaN  51000.0           HR  2021-03-17
# ...

# %%
df=df.dropna(subset=['name']).copy()
df
# Out:
#     id     name   age   salary   department   join_date
# 0    1    Alice  25.0  50000.0           HR  2021-01-15
# 1    2      Bob   NaN  60000.0  Engineering  2020-06-20
# 2    3  Charlie  35.0      NaN  Engineering  2019-03-10
# 3    4    David  29.0  55000.0          NaN  2022-08-01
# 4    5      Eva   NaN  48000.0           HR         NaN
# 6    7    Frank  28.0  52000.0  Engineering  2021-09-12
# 7    8    Grace   NaN  58000.0           HR  2020-02-18
# 8    9   Hannah  31.0      NaN    Marketing  2019-07-25
# 9   10      Ian  45.0  80000.0      Finance         NaN
# 10  11     Jack  27.0  48000.0          NaN  2021-11-05
# 11  12    Karen  34.0  62000.0  Engineering  2018-04-14
# 12  13     Liam   NaN  54000.0           HR  2022-01-09
# 13  14      Mia  26.0      NaN    Marketing  2020-05-21
# 14  15     Noah  38.0  72000.0      Finance  2017-10-30
# 15  16   Olivia   NaN  51000.0           HR  2021-03-17
# 16  17     Paul  41.0  69000.0          NaN  2016-08-19
# ...

# %%
mean_age=df['age'].mean()
mean_age
# Out:
# np.float64(33.15909090909091)

# %%
df['age']=df['age'].fillna(mean_age)
df
# Out:
#     id     name        age   salary   department   join_date
# 0    1    Alice  25.000000  50000.0           HR  2021-01-15
# 1    2      Bob  33.159091  60000.0  Engineering  2020-06-20
# 2    3  Charlie  35.000000      NaN  Engineering  2019-03-10
# 3    4    David  29.000000  55000.0          NaN  2022-08-01
# 4    5      Eva  33.159091  48000.0           HR         NaN
# 6    7    Frank  28.000000  52000.0  Engineering  2021-09-12
# 7    8    Grace  33.159091  58000.0           HR  2020-02-18
# 8    9   Hannah  31.000000      NaN    Marketing  2019-07-25
# 9   10      Ian  45.000000  80000.0      Finance         NaN
# 10  11     Jack  27.000000  48000.0          NaN  2021-11-05
# 11  12    Karen  34.000000  62000.0  Engineering  2018-04-14
# 12  13     Liam  33.159091  54000.0           HR  2022-01-09
# 13  14      Mia  26.000000      NaN    Marketing  2020-05-21
# 14  15     Noah  38.000000  72000.0      Finance  2017-10-30
# ...

# %%
median_salary=df['salary'].median()
median_salary
# Out:
# np.float64(59000.0)

# %%
df['salary']=df['salary'].fillna(median_salary)
df
# Out:
#     id     name        age   salary   department   join_date
# 0    1    Alice  25.000000  50000.0           HR  2021-01-15
# 1    2      Bob  33.159091  60000.0  Engineering  2020-06-20
# 2    3  Charlie  35.000000  59000.0  Engineering  2019-03-10
# 3    4    David  29.000000  55000.0          NaN  2022-08-01
# 4    5      Eva  33.159091  48000.0           HR         NaN
# 6    7    Frank  28.000000  52000.0  Engineering  2021-09-12
# 7    8    Grace  33.159091  58000.0           HR  2020-02-18
# 8    9   Hannah  31.000000  59000.0    Marketing  2019-07-25
# 9   10      Ian  45.000000  80000.0      Finance         NaN
# 10  11     Jack  27.000000  48000.0          NaN  2021-11-05
# 11  12    Karen  34.000000  62000.0  Engineering  2018-04-14
# 12  13     Liam  33.159091  54000.0           HR  2022-01-09
# 13  14      Mia  26.000000  59000.0    Marketing  2020-05-21
# 14  15     Noah  38.000000  72000.0      Finance  2017-10-30
# ...

# %%
df['department']=df['department'].fillna('Unknown')
df.head()
# Out:
#    id     name        age   salary   department   join_date
# 0   1    Alice  25.000000  50000.0           HR  2021-01-15
# 1   2      Bob  33.159091  60000.0  Engineering  2020-06-20
# 2   3  Charlie  35.000000  59000.0  Engineering  2019-03-10
# 3   4    David  29.000000  55000.0      Unknown  2022-08-01
# 4   5      Eva  33.159091  48000.0           HR         NaN

# %%
df['join_date']=pd.to_datetime(df['join_date'],errors='coerce')
df.head()
# Out:
#    id     name        age   salary   department  join_date
# 0   1    Alice  25.000000  50000.0           HR 2021-01-15
# 1   2      Bob  33.159091  60000.0  Engineering 2020-06-20
# 2   3  Charlie  35.000000  59000.0  Engineering 2019-03-10
# 3   4    David  29.000000  55000.0      Unknown 2022-08-01
# 4   5      Eva  33.159091  48000.0           HR        NaT

# %%
df=df.dropna(subset='join_date')
df.head()
# Out:
#    id     name        age   salary   department  join_date
# 0   1    Alice  25.000000  50000.0           HR 2021-01-15
# 1   2      Bob  33.159091  60000.0  Engineering 2020-06-20
# 2   3  Charlie  35.000000  59000.0  Engineering 2019-03-10
# 3   4    David  29.000000  55000.0      Unknown 2022-08-01
# 6   7    Frank  28.000000  52000.0  Engineering 2021-09-12

# %%
df['join_date'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.reset_index(drop=True)
# Out:
#     id     name        age   salary   department  join_date
# 0    1    Alice  25.000000  50000.0           HR 2021-01-15
# 1    2      Bob  33.159091  60000.0  Engineering 2020-06-20
# 2    3  Charlie  35.000000  59000.0  Engineering 2019-03-10
# 3    4    David  29.000000  55000.0      Unknown 2022-08-01
# 4    7    Frank  28.000000  52000.0  Engineering 2021-09-12
# 5    8    Grace  33.159091  58000.0           HR 2020-02-18
# 6    9   Hannah  31.000000  59000.0    Marketing 2019-07-25
# 7   11     Jack  27.000000  48000.0      Unknown 2021-11-05
# 8   12    Karen  34.000000  62000.0  Engineering 2018-04-14
# 9   13     Liam  33.159091  54000.0           HR 2022-01-09
# 10  14      Mia  26.000000  59000.0    Marketing 2020-05-21
# 11  15     Noah  38.000000  72000.0      Finance 2017-10-30
# 12  16   Olivia  33.159091  51000.0           HR 2021-03-17
# 13  17     Paul  41.000000  69000.0      Unknown 2016-08-19
# 14  18    Quinn  33.000000  59000.0  Engineering 2019-12-01
# ...

# %%
df.fillna(method='ffill')
# Out:
# C:\Users\user name\AppData\Local\Temp\ipykernel_1196\253117906.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill')
#     id     name        age   salary   department  join_date
# 0    1    Alice  25.000000  50000.0           HR 2021-01-15
# 1    2      Bob  33.159091  60000.0  Engineering 2020-06-20
# 2    3  Charlie  35.000000  59000.0  Engineering 2019-03-10
# 3    4    David  29.000000  55000.0      Unknown 2022-08-01
# 6    7    Frank  28.000000  52000.0  Engineering 2021-09-12
# 7    8    Grace  33.159091  58000.0           HR 2020-02-18
# 8    9   Hannah  31.000000  59000.0    Marketing 2019-07-25
# 10  11     Jack  27.000000  48000.0      Unknown 2021-11-05
# 11  12    Karen  34.000000  62000.0  Engineering 2018-04-14
# 12  13     Liam  33.159091  54000.0           HR 2022-01-09
# 13  14      Mia  26.000000  59000.0    Marketing 2020-05-21
# ...

# %%
df.fillna(method='ffill', inplace=True)
df.head()
# Out:
# C:\Users\user name\AppData\Local\Temp\ipykernel_1196\2766238617.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)
# C:\Users\user name\AppData\Local\Temp\ipykernel_1196\2766238617.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.fillna(method='ffill', inplace=True)
#    id     name        age   salary   department  join_date
# 0   1    Alice  25.000000  50000.0           HR 2021-01-15
# 1   2      Bob  33.159091  60000.0  Engineering 2020-06-20
# 2   3  Charlie  35.000000  59000.0  Engineering 2019-03-10
# 3   4    David  29.000000  55000.0      Unknown 2022-08-01
# 6   7    Frank  28.000000  52000.0  Engineering 2021-09-12

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, 0 to 59
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          51 non-null     int64
#  1   name        51 non-null     object
#  2   age         51 non-null     float64
#  3   salary      51 non-null     float64
#  4   department  51 non-null     object
#  5   join_date   51 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1), object(2)
# memory usage: 2.8+ KB

# %%
df['age']=df['age'].astype(int)
# Out:
# C:\Users\user name\AppData\Local\Temp\ipykernel_1196\1889264292.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['age']=df['age'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, 0 to 59
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          51 non-null     int64
#  1   name        51 non-null     object
#  2   age         51 non-null     int64
#  3   salary      51 non-null     float64
#  4   department  51 non-null     object
#  5   join_date   51 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(2), object(2)
# memory usage: 2.8+ KB

# %%
df['salary']=df['salary'].astype(int)
# Out:
# C:\Users\user name\AppData\Local\Temp\ipykernel_1196\461322919.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['salary']=df['salary'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, 0 to 59
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          51 non-null     int64
#  1   name        51 non-null     object
#  2   age         51 non-null     int64
#  3   salary      51 non-null     int64
#  4   department  51 non-null     object
#  5   join_date   51 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 2.8+ KB

# %%
df.head()
# Out:
#    id     name  age  salary   department  join_date
# 0   1    Alice   25   50000           HR 2021-01-15
# 1   2      Bob   33   60000  Engineering 2020-06-20
# 2   3  Charlie   35   59000  Engineering 2019-03-10
# 3   4    David   29   55000      Unknown 2022-08-01
# 6   7    Frank   28   52000  Engineering 2021-09-12

# %%
df['bonus']=df['salary']* 0.01
df.head()
# Out:
# C:\Users\user name\AppData\Local\Temp\ipykernel_1196\3873808105.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['bonus']=df['salary']* 0.01
#    id     name  age  salary   department  join_date  bonus
# 0   1    Alice   25   50000           HR 2021-01-15  500.0
# 1   2      Bob   33   60000  Engineering 2020-06-20  600.0
# 2   3  Charlie   35   59000  Engineering 2019-03-10  590.0
# 3   4    David   29   55000      Unknown 2022-08-01  550.0
# 6   7    Frank   28   52000  Engineering 2021-09-12  520.0

# %%
df['bonus']=df['bonus'].astype(int)
df.head()
# Out:
# C:\Users\user name\AppData\Local\Temp\ipykernel_1196\3215074462.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['bonus']=df['bonus'].astype(int)
#    id     name  age  salary   department  join_date  bonus
# 0   1    Alice   25   50000           HR 2021-01-15    500
# 1   2      Bob   33   60000  Engineering 2020-06-20    600
# 2   3  Charlie   35   59000  Engineering 2019-03-10    590
# 3   4    David   29   55000      Unknown 2022-08-01    550
# 6   7    Frank   28   52000  Engineering 2021-09-12    520

# %%
df['performance_score']=np.random.randint(1,6,size=len(df))
df.head()
# Out:
# C:\Users\user name\AppData\Local\Temp\ipykernel_1196\1847430066.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['performance_score']=np.random.randint(1,6,size=len(df))
#    id     name  age  salary   department  join_date  bonus  performance_score
# 0   1    Alice   25   50000           HR 2021-01-15    500                  2
# 1   2      Bob   33   60000  Engineering 2020-06-20    600                  5
# 2   3  Charlie   35   59000  Engineering 2019-03-10    590                  2
# 3   4    David   29   55000      Unknown 2022-08-01    550                  3
# 6   7    Frank   28   52000  Engineering 2021-09-12    520                  5

# %%
df.reset_index(drop=True)
# Out:
#     id     name  age  salary   department  join_date  bonus  performance_score
# 0    1    Alice   25   50000           HR 2021-01-15    500                  2
# 1    2      Bob   33   60000  Engineering 2020-06-20    600                  5
# 2    3  Charlie   35   59000  Engineering 2019-03-10    590                  2
# 3    4    David   29   55000      Unknown 2022-08-01    550                  3
# 4    7    Frank   28   52000  Engineering 2021-09-12    520                  5
# 5    8    Grace   33   58000           HR 2020-02-18    580                  3
# 6    9   Hannah   31   59000    Marketing 2019-07-25    590                  5
# 7   11     Jack   27   48000      Unknown 2021-11-05    480                  4
# 8   12    Karen   34   62000  Engineering 2018-04-14    620                  1
# 9   13     Liam   33   54000           HR 2022-01-09    540                  3
# 10  14      Mia   26   59000    Marketing 2020-05-21    590                  1
# ...

# %%
df=df.to_csv("employees_cleaned.csv")
